# %% [markdown]
# # Подготовка

# %% [markdown]
# Данные шаги нужно выполнить как для обучения модели, так и для синтеза готовой моделью.

# %% [markdown]
# ## Скачиваем репозиторий

# %%
# !rm -r ./tts_homework3
# !git clone https://github.com/zakoden/tts_homework3.git
# Out:
# rm: cannot remove './tts_homework3': No such file or directory
# Cloning into 'tts_homework3'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 170 (delta 66), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (170/170), 44.06 KiB | 6.29 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %% [markdown]
# ## Установка библиотек

# %% [markdown]
# Сначала скачиваем используемый репозиторий.

# %%
# !bash ./tts_homework3/load_dependency.sh
# Out:
# Cloning into 'FastSpeech'...
# remote: Enumerating objects: 948, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 948 (delta 88), reused 191 (delta 87), pack-reused 750
# Receiving objects: 100% (948/948), 17.76 MiB | 18.34 MiB/s, done.
# Resolving deltas: 100% (458/458), done.

# %% [markdown]
# Теперь устанавливаем необходимые библиотеки.

# %%
# !pip install -r ./tts_homework3/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 750.6 MB 11 kB/s
# ...
#      |████████████████████████████████| 21.0 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 451 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 55.7 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 51.2 MB/s
# ...
#      |████████████████████████████████| 235 kB 70.2 MB/s
# ...
#      |████████████████████████████████| 214 kB 64.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 115 kB 62.8 MB/s
# ...
#      |████████████████████████████████| 182 kB 64.7 MB/s
# ...
#      |████████████████████████████████| 212 kB 64.3 MB/s
# ...
#      |████████████████████████████████| 127 kB 64.2 MB/s
# ...
#      |████████████████████████████████| 168 kB 65.1 MB/s
# ...
#      |████████████████████████████████| 182 kB 64.7 MB/s
# ...

# %% [markdown]
# ## Загрузка данных

# %%
# вроде исправляет баг с gdown
# !pip install gdown==4.5.4 --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...

# %% [markdown]
# (выполняется минут 10)

# %%
# !bash ./tts_homework3/load_data.sh
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# mels/ljspeech-mel-00650.npy
# mels/ljspeech-mel-01307.npy
# mels/ljspeech-mel-06651.npy
# mels/ljspeech-mel-11249.npy
# mels/ljspeech-mel-12993.npy
# mels/ljspeech-mel-10276.npy
# mels/ljspeech-mel-06344.npy
# mels/ljspeech-mel-04036.npy
# mels/ljspeech-mel-07839.npy
# mels/ljspeech-mel-06742.npy
# mels/ljspeech-mel-01960.npy
# mels/ljspeech-mel-12438.npy
# mels/ljspeech-mel-09687.npy
# mels/ljspeech-mel-10731.npy
# mels/ljspeech-mel-10019.npy
# mels/ljspeech-mel-04562.npy
# mels/ljspeech-mel-03962.npy
# mels/ljspeech-mel-08118.npy
# mels/ljspeech-mel-09256.npy
# mels/ljspeech-mel-02595.npy
# mels/ljspeech-mel-07329.npy
# mels/ljspeech-mel-06735.npy
# mels/ljspeech-mel-07776.npy
# mels/ljspeech-mel-03175.npy
# mels/ljspeech-mel-04500.npy
# mels/ljspeech-mel-08713.npy
# mels/ljspeech-mel-05277.npy
# mels/ljspeech-mel-02754.npy
# mels/ljspeech-mel-06713.npy
# mels/ljspeech-mel-12452.npy
# mels/ljspeech-mel-10649.npy
# ...

# %% [markdown]
# # Синтез

# %% [markdown]
# ## Загрузка весов модели

# %% [markdown]
# Загружаем финальную модель, которая обучалась 180 тысяч шагов.

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1v88MKcA7dx8fImJEj7EhaHxfBoWOangx/view?usp=share_link
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1v88MKcA7dx8fImJEj7EhaHxfBoWOangx
# To: /content/checkpoint_180000.pth.tar
# 100% 313M/313M [00:01<00:00, 222MB/s]

# %% [markdown]
# ## Синтез аудио

# %% [markdown]
# Запускаем скрипт test.py со следующими параметрами:
# -c ./checkpoint_180000.pth.tar, чекпоинт модели
# -i test_example.txt, где каждая строчка файла имеет вид `"1.0 1.0 1.0 text"`. Первые три числа отвечают за коэффициенты duration, pitch, energy у генерируемого аудио и затем идёт текст для синтеза.
# -o output, папка с выходными аудио с названиями вида `d=(0.5)_p=(1.0)_e=(0.5)_2_waveglow.wav`, в которых указаны значения трёх коэффициентов и затем индекс текста в исходном файле.

# %%
# пример входного файла
# !cat ./tts_homework3/test_example.txt
# Out:
# 1.0 1.0 1.0 A defibrillator is a device that gives a high energy electric shock to the heart of someone who is in cardiac arrest
# 1.5 0.5 1.5 Massachusetts Institute of Technology may be best known for its math, science and engineering education
# 0.5 1.0 0.5 Wasserstein distance or Kantorovich Rubinstein metric is a distance function defined between probability distributions on a given metric space

# %%
# !python ./tts_homework3/test.py -c ./checkpoint_180000.pth.tar -i ./tts_homework3/test_example.txt -o ./tts_homework3/output
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose 'Don't visualize my results'
# wandb: Tracking run with wandb version 0.13.5
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'glow.WaveGlow' has changed. Saved a reverse patch to WaveGlow.patch. Run `patch -p0 < WaveGlow.patch` to revert your changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.conv.ConvTranspose1d' has changed. Saved a reverse patch to ConvTranspose1d.patch. Run `patch -p0 < ConvTranspose1d.patch` to revert your changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...

# %%
from IPython import display

# %%
display.Audio("./tts_homework3/output/d=(1.0)_p=(1.0)_e=(1.0)_0_waveglow.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display.Audio("./tts_homework3/output/d=(1.5)_p=(0.5)_e=(1.5)_1_waveglow.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
display.Audio("./tts_homework3/output/d=(0.5)_p=(1.0)_e=(0.5)_2_waveglow.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Обучение

# %% [markdown]
# Для воспроизведение достаточно запустить следующий скрипт и взять чекпоинт `checkpoint_180000.pth.tar` (после 180 тысяч итераций).

# %%
# !python ./tts_homework3/train.py
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose 'Don't visualize my results'
# wandb: Tracking run with wandb version 0.13.5
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
#  11% 1501/13100 [03:07<24:09,  8.00it/s]
# cost 198.18s to load all data into buffer.
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py:786: SourceChangeWarning: source code of class 'glow.WaveGlow' has changed. Saved a reverse patch to WaveGlow.patch. Run `patch -p0 < WaveGlow.patch` to revert your changes.
#   warnings.warn(msg, SourceChangeWarning)
# ...
